# %%
from amadeus import Client, ResponseError
import pandas as pd
import os

client_id = os.environ.get('AWS_ACCESS_KEY_ID')
client_secret = os.environ.get('AWS_SECRET_ACCESS_KEY')

amadeus = Client(
    client_id=client_id,
    client_secret=client_secret
)

origin_city_code = 'MAD'  # Madrid

years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

for year in years:
    year_folder = f'destination_{year}'
    os.makedirs(year_folder, exist_ok=True)  # Crée le dossier s'il n'existe pas
    
    for month in months:
        period = f'{year}-{month}'
        try:
            response = amadeus.travel.analytics.air_traffic.traveled.get(
                originCityCode=origin_city_code,
                period=period,
                sort='analytics.travelers.score'
            )
            data = response.data
        except ResponseError as error:
            data = []
            print(f"Failed to fetch data for {period}. Error: {error}")
        
        csv_file = os.path.join(year_folder, f'{year}_{month}.csv')
        df = pd.DataFrame(data)
        df.to_csv(csv_file, index=False)
        print(f"Data for {period} saved to {csv_file}")
# Out:
# Data for 2017-01 saved to destination_2017\2017_01.csv
# Data for 2017-02 saved to destination_2017\2017_02.csv
# Data for 2017-03 saved to destination_2017\2017_03.csv
# Data for 2017-04 saved to destination_2017\2017_04.csv
# Data for 2017-05 saved to destination_2017\2017_05.csv
# Data for 2017-06 saved to destination_2017\2017_06.csv
# Data for 2017-07 saved to destination_2017\2017_07.csv
# Data for 2017-08 saved to destination_2017\2017_08.csv
# Data for 2017-09 saved to destination_2017\2017_09.csv
# Data for 2017-10 saved to destination_2017\2017_10.csv
# Data for 2017-11 saved to destination_2017\2017_11.csv
# Data for 2017-12 saved to destination_2017\2017_12.csv
# Data for 2018-01 saved to destination_2018\2018_01.csv
# Data for 2018-02 saved to destination_2018\2018_02.csv
# Data for 2018-03 saved to destination_2018\2018_03.csv
# Data for 2018-04 saved to destination_2018\2018_04.csv
# Data for 2018-05 saved to destination_2018\2018_05.csv
# Data for 2018-06 saved to destination_2018\2018_06.csv
# Data for 2018-07 saved to destination_2018\2018_07.csv
# Data for 2018-08 saved to destination_2018\2018_08.csv
# Data for 2018-09 saved to destination_2018\2018_09.csv
# Data for 2018-10 saved to destination_2018\2018_10.csv
# Data for 2018-11 saved to destination_2018\2018_11.csv
# Data for 2018-12 saved to destination_2018\2018_12.csv
# Data for 2019-01 saved to destination_2019\2019_01.csv
# Data for 2019-02 saved to destination_2019\2019_02.csv
# Data for 2019-03 saved to destination_2019\2019_03.csv
# Data for 2019-04 saved to destination_2019\2019_04.csv
# Data for 2019-05 saved to destination_2019\2019_05.csv
# Data for 2019-06 saved to destination_2019\2019_06.csv
# Data for 2019-07 saved to destination_2019\2019_07.csv
# Data for 2019-08 saved to destination_2019\2019_08.csv
# Data for 2019-09 saved to destination_2019\2019_09.csv
# Data for 2019-10 saved to destination_2019\2019_10.csv
# Data for 2019-11 saved to destination_2019\2019_11.csv
# Data for 2019-12 saved to destination_2019\2019_12.csv
# Data for 2020-01 saved to destination_2020\2020_01.csv
# Data for 2020-02 saved to destination_2020\2020_02.csv
# Data for 2020-03 saved to destination_2020\2020_03.csv
# Data for 2020-04 saved to destination_2020\2020_04.csv
# Data for 2020-05 saved to destination_2020\2020_05.csv
# Data for 2020-06 saved to destination_2020\2020_06.csv
# Data for 2020-07 saved to destination_2020\2020_07.csv
# Data for 2020-08 saved to destination_2020\2020_08.csv
# Data for 2020-09 saved to destination_2020\2020_09.csv
# Data for 2020-10 saved to destination_2020\2020_10.csv
# Data for 2020-11 saved to destination_2020\2020_11.csv
# Data for 2020-12 saved to destination_2020\2020_12.csv
# Data for 2021-01 saved to destination_2021\2021_01.csv
# Data for 2021-02 saved to destination_2021\2021_02.csv
# Data for 2021-03 saved to destination_2021\2021_03.csv
# Data for 2021-04 saved to destination_2021\2021_04.csv
# Data for 2021-05 saved to destination_2021\2021_05.csv
# Data for 2021-06 saved to destination_2021\2021_06.csv
# Data for 2021-07 saved to destination_2021\2021_07.csv
# Data for 2021-08 saved to destination_2021\2021_08.csv
# Data for 2021-09 saved to destination_2021\2021_09.csv
# Data for 2021-10 saved to destination_2021\2021_10.csv
# Data for 2021-11 saved to destination_2021\2021_11.csv
# Data for 2021-12 saved to destination_2021\2021_12.csv
# Data for 2022-01 saved to destination_2022\2022_01.csv
# Data for 2022-02 saved to destination_2022\2022_02.csv
# Data for 2022-03 saved to destination_2022\2022_03.csv
# Data for 2022-04 saved to destination_2022\2022_04.csv
# Data for 2022-05 saved to destination_2022\2022_05.csv
# Data for 2022-06 saved to destination_2022\2022_06.csv
# Data for 2022-07 saved to destination_2022\2022_07.csv
# Data for 2022-08 saved to destination_2022\2022_08.csv
# Data for 2022-09 saved to destination_2022\2022_09.csv
# Data for 2022-10 saved to destination_2022\2022_10.csv
# Data for 2022-11 saved to destination_2022\2022_11.csv
# Data for 2022-12 saved to destination_2022\2022_12.csv
# Data for 2023-01 saved to destination_2023\2023_01.csv
# Data for 2023-02 saved to destination_2023\2023_02.csv
# Data for 2023-03 saved to destination_2023\2023_03.csv
# Data for 2023-04 saved to destination_2023\2023_04.csv
# Data for 2023-05 saved to destination_2023\2023_05.csv
# Data for 2023-06 saved to destination_2023\2023_06.csv
# Data for 2023-07 saved to destination_2023\2023_07.csv
# Data for 2023-08 saved to destination_2023\2023_08.csv
# Data for 2023-09 saved to destination_2023\2023_09.csv
# Data for 2023-10 saved to destination_2023\2023_10.csv
# Data for 2023-11 saved to destination_2023\2023_11.csv
# Data for 2023-12 saved to destination_2023\2023_12.csv
